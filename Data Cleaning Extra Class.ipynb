# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/training-ml/Files/main/raw_data.csv"
df = pd.read_csv(url)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9     NaN                  NaN         NaN                            NaN
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# question 1

index = np.where(df["id"].isna() == True)

# %%
df.loc[9] = [210,"Jim Carry","01/01/1997","jim.carry@gmail.com","Male","Amazone","USA",12349.533,2365]

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1997            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# Question 2

email ={3:"gramecroser.@gmail.com",6:"modestbetterson@gmail.com"}
df["email"].fillna(email,inplace=True)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018         gramecroser.@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018      modestbetterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1997            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
# Question 3

df["Country"].unique()
# Out:
# array(['India', 'USA', 'UAS', 'Canada', nan, 'Russia'], dtype=object)

# %%
df["Country"].replace('UAS','USA', inplace=True)
df["Country"].fillna(df['Country'].mode()[0],inplace=True)

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018         gramecroser.@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018      modestbetterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1997            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
from sklearn.impute import SimpleImputer, KNNImputer

# %%
df['Income.1'].replace('$', np.NaN,inplace=True)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018         gramecroser.@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018      modestbetterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1997            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['Income.1']=df['Income.1'].str.replace('$','')
df
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_4584\3064341009.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Income.1']=df['Income.1'].str.replace('$','')
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018         gramecroser.@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018      modestbetterson@gmail.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            13 non-null     object
#  8   Income.2            18 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 1.5+ KB

# %%
df['Income.1']=df['Income.1'].astype('float64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            13 non-null     float64
#  8   Income.2            18 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
imputer = SimpleImputer()
imputed_data = imputer.fit_transform(df[['Income.1','Income.2']])
df[['Income.1','Income.2']]= imputed_data

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018         gramecroser.@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018      modestbetterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1997            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['Total_income'] = df[['Income.1','Income.2']].sum(axis=1)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018         gramecroser.@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018      modestbetterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry  01/01/1997            jim.carry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %% [markdown]
# ### 15 Sep 2023

# %%
# Quetion No 2
First_name = []
Last_name = []
for i in df['Employee Full Name']:
    First_name.append(i.split(" ")[0])
    Last_name.append(i.split(" ")[1])

# %%
len(First_name),len(Last_name)
# Out:
# (20, 20)

# %%
# Question No 3
df.insert(0,"First_name",First_name)
df.insert(1,'Last_name',Last_name)
df
# Out:
#    First_name    Last_name     id   Employee Full Name         DOB  \
# 0       Salim        Pound  201.0          Salim Pound  02-12-2018
# 1    Madelene        Lutas  202.0       Madelene Lutas   9/20/2018
# 2       Dolli   Swanbourne  203.0     Dolli Swanbourne  11/18/2018
# 3      Graeme     Croisier  204.0      Graeme Croisier   9/29/2018
# 4     Jillana       Physic  205.0       Jillana Physic   4/19/2018
# 5      Anetta     Yokelman  206.0      Anetta Yokelman   4/26/2018
# 6     Modesta    Batterson  207.0    Modesta Batterson   3/28/2018
# 7      Melina         Boon  208.0          Melina Boon  12/18/2017
# 8        Nomi         Warn  209.0            Nomi Warn   1/16/2018
# 9         Jim        Carry  210.0            Jim Carry  01/01/1997
# 10   Charleen        Auden  211.0       Charleen Auden   4/15/2018
# 11       Dame       Povele  212.0          Dame Povele   6/26/2018
# 12      Jesse  Engelbrecht  213.0    Jesse Engelbrecht   4/16/2018
# ...

# %%
# Question no 1
df['DOB']=df['DOB'].str.replace('-','/')
df.head()
# Out:
#   First_name   Last_name     id Employee Full Name         DOB  \
# 0      Salim       Pound  201.0        Salim Pound  02/12/2018
# 1   Madelene       Lutas  202.0     Madelene Lutas   9/20/2018
# 2      Dolli  Swanbourne  203.0   Dolli Swanbourne  11/18/2018
# 3     Graeme    Croisier  204.0    Graeme Croisier   9/29/2018
# 4    Jillana      Physic  205.0     Jillana Physic   4/19/2018
#
#                           email  gender    Company Country      Income.1  \
# 0           spound0@spotify.com    Male     Google   India  46476.638081
# 1                mlutas1@si.edu  Female     Amazon     USA  54174.687948
# 2  dswanbourne2@istockphoto.com  Female      Intel     USA  43467.240728
# 3        gramecroser.@gmail.com    Male  Accenture  Canada  46784.630879
# 4       jphysic4@yellowbook.com  Female  Accenture   India  57486.495560
#
#    Income.2  Total_income
# 0     529.0  47005.638081
# 1     720.0  54894.687948
# 2     234.0  43701.240728
# 3     657.0  47441.630879
# ...

# %%
df['DOB'] = pd.to_datetime(df['DOB'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   First_name          20 non-null     object
#  1   Last_name           20 non-null     object
#  2   id                  20 non-null     float64
#  3   Employee Full Name  20 non-null     object
#  4   DOB                 20 non-null     datetime64[ns]
#  5   email               20 non-null     object
#  6   gender              20 non-null     object
#  7   Company             20 non-null     object
#  8   Country             20 non-null     object
#  9   Income.1            20 non-null     float64
#  10  Income.2            20 non-null     float64
#  11  Total_income        20 non-null     float64
# dtypes: datetime64[ns](1), float64(4), object(7)
# memory usage: 2.0+ KB

# %%
# Question 4
Salaries_by_comp_ctry = df.groupby(['Country','Company'])
Salaries_by_comp_ctry.mean()
# Out:
#                            id      Income.1     Income.2  Total_income
# Country Company
# Canada  Accenture  204.000000  46784.630879   657.000000  47441.630879
#         Amazon     213.000000  55804.925687  1125.722222  56930.647910
#         Google     214.000000  44191.473128    46.000000  44237.473128
# India   Accenture  205.000000  57486.495560  1947.000000  59433.495560
#         Amazon     212.666667  40233.997150  1702.333333  41936.330483
#         Google     211.333333  48892.788476  1031.666667  49924.455143
#         Intel      206.500000  43467.240728   492.000000  43959.240728
# Russia  Amazon     219.000000   7101.351970  1952.000000   9053.351970
#         Google     215.000000  43467.240728   568.000000  44035.240728
#         Intel      220.000000  43363.078707  1668.000000  45031.078707
# USA     Accenture  211.000000  47119.174780   920.000000  48039.174780
#         Amazon     205.500000  41388.561663   922.861111  42311.422774
# ...
